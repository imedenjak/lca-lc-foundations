# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# My training data goes up to June 2024. I don’t have real-time internet access by default, so I can’t fetch new events or updates after that unless you enable browsing or provide sources.
#
# If you need current information, you can:
# - Enable a browsing tool (if available in your setup) for me to search the web.
# - Paste articles, links, or key details and I can help analyze or summarize.
# - Ask me for general principles or historical context I can still rely on.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured city",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.8755427,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=jKlTyBxpyT4',
#    'title': "San Francisco's new mayor is starting to unite the fractured city",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on,',
#    'score': 0.86413884,
#    'raw_content': None},
#   {'url': 'https://www.theguardian.com/us-news/2024/nov/07/san-francisco-mayor-election',
#    'title': 'Levi Strauss heir Daniel Lurie elected mayor of San Francisco',
#    'content': '... San Francisco non-profit he founded. He defeated several Democratic challengers, including the current mayor, London Breed, in an election',
#    'score': 0.84767824,
#    'raw_content': None},
#   {'url': 'https://www.cbsnews.com/sanfrancisco/news/san-francisco-mayor-elect-daniel-lurie-claims-victory-outlines-vision-for-city/',
#    'title': 'San Francisco Mayor-elect Daniel Lurie claims victory, outlines ...',
#    'content': "San Francisco's Mayor-elect Daniel Lurie declared victory Friday morning as he addressed the city for the first time since incumbent Mayor London Breed",
#    'score': 0.8386933,
#    'raw_content': None},
#   {'url': 'https://en.wikipedia.org/wiki/Daniel_Lurie',
#    'title': 'Daniel Lurie - Wikipedia',
#    'content': 'Daniel Lawrence Lurie (born February 4, 1977) is an American politician and philanthropist who is the 46th and incumbent mayor of San Francisco,',
#    'score': 0.8066246,
#    'raw_content': None}],
#  'response_time': 0.58,
#  'request_id': '916d093b-3a1a-4a86-84af-9a5129d267f0'}

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='57332e15-0ec8-4486-b4b1-cae18dc5c431'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 414, 'prompt_tokens': 133, 'total_tokens': 547, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHlqi6U4gglmT9E1yqcsCTxGfGh40', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cd6a8-4bbe-75f1-a206-b45131275f76-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of San Francisco 2026'}, 'id': 'call_9DNctGgb2mIiu2voNefa1Epr', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 133, 'output_tokens': 414, 'total_tokens': 547, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}),
#  ToolMessage(content='{"query": "current mayor of San Francisco 2026", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/watch?v=LvoD21z_inM", "title": "Mayor Daniel Lurie\'s State of the City 2026 - YouTube", "content": "Watch San Francisco\'s Mayor Daniel Lurie give his State of the City address.", "score": 0.9992022, "raw_content": null}, {"url": "https://www.ktvu.com/news/sf-mayor-reflects-year-draws-close", "title": "Lurie reflects on first year in office as 2025 draws to a close - KTVU", "content": "Mayor Daniel Lurie is touting a transformational year, saying San Francisco has turned the corner and better things await the city in 2026.", "score": 0.99827254, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/Mayor_of_San_Francisco", "title": "Mayor of San Francisco - Wikipedia", "content": "Incumbent Daniel Lurie. since January 8, 2025. Government of San Francisco ; Incumbent Daniel Lurie. since January 8, 2025. Government of San Francisco · His", "score": 0.9964619, "raw_content": null}, {"url": "https://www.sf.gov/departments--office-mayor", "title": "Office of the Mayor - SF.gov", "content": "Daniel Lurie is the 46th Mayor of the City and County of San ... Mayor Lurie Announces Appointments to San Francisco Committees, Commissions February 27, 2026.", "score": 0.99596137, "raw_content": null}, {"url": "https://sfstandard.com/2026/01/15/san-francisco-daniel-lurie-state-of-the-city/", "title": "Daniel Lurie was the public safety mayor. Now he\'s trying to be the ...", "content": "Daniel Lurie was the public safety mayor. Now he\'s trying to be the affordability guy. In his first State of the City speech, he placed the", "score": 0.9923044, "raw_content": null}], "response_time": 0.62, "request_id": "3b9a2ae7-4107-49dc-abe4-07b433672ac0"}', name='web_search', id='d060b015-cd43-4c4e-b31b-bc8d510e6e22', tool_call_id='call_9DNctGgb2mIiu2voNefa1Epr'),
#  AIMessage(content='Daniel Lurie is the current mayor of San Francisco. He took office on January 8, 2025, as the city’s 46th mayor. If you’d like, I can pull up the latest news or official statements about his tenure.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 636, 'prompt_tokens': 698, 'total_tokens': 1334, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHlqnzVCoY6hkpQCDcTsCo1kcPSPK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cd6a8-6087-7881-a8af-c1baf3cb9838-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 698, 'output_tokens': 636, 'total_tokens': 1334, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
