# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or cities, so it has no capital. \n\nIf you’re looking for a fictional option for a story, you could name a capital something like:\n- Lunapolis\n- Selene City\n- Craterport\n- Arcas\n\nWant me to come up with a brief backstory for a lunar capital?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 535, 'prompt_tokens': 13, 'total_tokens': 548, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHcwjSOpurpzq9KImgiYrQFOCcyJv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cd49e-1864-70e3-88b2-739c01aff67a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 535, 'total_tokens': 548, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or cities, so it has no capital.
#
# If you’re looking for a fictional option for a story, you could name a capital something like:
# - Lunapolis
# - Selene City
# - Craterport
# - Arcas
#
# Want me to come up with a brief backstory for a lunar capital?

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DHcwjSOpurpzq9KImgiYrQFOCcyJv',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 535,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 448,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 548}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital. If you’re writing fiction, you could invent a capital—examples: Lunopolis, Selene City, or Luna City. Want suggestions tailored to a specific setting? Tell me the vibe (futuristic, colonial, etc.).

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='df2d651c-dd4a-418c-91b1-92af1bed3256'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government, so it has no capital city. If you’re thinking of a fictional or future scenario, you can imagine any place you like, but in reality there is no capital.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 571, 'prompt_tokens': 13, 'total_tokens': 584, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHd3uEBNxMJS8kkraE727DqAKGfwe', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cd4a4-e46c-7d90-bb98-6ef7d74172aa-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 571, 'total_tokens': 584, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital city. If you’re thinking of a fictional or future scenario, you can imagine any place you like, but in reality there is no capital.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='64dc0ff8-a4c5-4ab1-96a9-e7e53ef10159'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='86a2b535-ba43-4946-9d5c-9b5f081decda', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='eb96ce84-bd45-45d8-9823-744ee40da3ee'),
#               AIMessage(content='Just to be clear: Luna City is fictional. There’s no real capital on the Moon. Here’s a detailed fictional snapshot you can use for worldbuilding, a story, or a game.\n\nQuick snapshot\n- Role: The political, cultural, and scientific capital of the Lunar Confederacy (or Lunar Commonwealth, depending on your setting).\n- Location vibe: A hub perched near the lunar south pole, on a crater rim where long periods of sunlight meet access to water ice in permanently shadowed regions.\n- Scale: A dense core city inside and around lava-tube caverns, ringed by greenhouses, research districts, and logistics corridors. An outer ring handles mining, energy, and transport.\n\nGeography and city layout\n- Core districts: \n  - Civic Quarter: government buildings, council chambers, museums, and universities.\n  - Research Arcades: labs for astrochemistry, biology, robotics, and terraforming research.\n  - Habitat Ring: apartment complexes, schools, hospitals, and cultural centers inside shielded domes.\n  - Port and Logistics Zone: spaceport interfaces, cargo yards, manufacturing, and maintenance.\n- Underground and surface integration: Habitats built inside lava tubes and artificial caverns; surface employs shielded modules and solar farms.\n- Transportation: Lunar maglev or rail transit, drone delivery corridors, EVA hubs for field work, and a pedestrian-friendly central promenade under a transparent skylight.\n\nGovernment and society\n- Governing body: Lunar Confederacy Council with representation from science, industry, education, security, health, culture, and environment. An elected Mayor of Luna City handles day-to-day administration.\n- Citizenship: Long-term residents obtain lunar citizenship with rights to resources, housing, and education. Collaboration agreements with Earth and other colonies shape immigration and trade.\n- Society: Multilingual and multicultural, with settlers, researchers, engineers, artists, and miners. Strong emphasis on education, healthcare, and self-sufficiency.\n\nInfrastructure and technology\n- Life support: Closed-loop air, water recycling, and hydroponic farms. Shielded habitats protect against radiation and micrometeoroids.\n- Energy: Solar arrays on the crater rim and in-field solar farms; some power beamed to key districts as a backup.\n- Resource workflow: Water ice mined from shadowed regions; oxygen extracted and recycled; regolith processed for construction and minerals; helium-3 and other lunar resources traded with Earth.\n- Communications: High-bandwidth relay network for lunar-Earth and interplanetary comms; deep-space research outposts connected to Luna City’s data core.\n\nEconomy and daily life\n- Key sectors: Scientific research and tech development, mining support services, 3D printing and fabrication, health care and biotech, education, and lunar tourism.\n- Daily life: Hydroponic farms supply fresh produce; education runs through universities with virtual and field components; culture thrives with lunar art, music, and storytelling unique to living in a low-gravity environment.\n- Tourism: Visitors can tour the solar farms, see ice-mining operations, and experience zero- and low-gravity recreational zones inside pressurized domes.\n\nCulture and landmarks\n- Notable districts and landmarks:\n  - Aurora Dome District: residential and cultural spaces with a translucent roof that shows starry skies.\n  - Port Lantern: a bright gateway area with a spaceport, public markets, and exhibition halls.\n  - Horizon Archives: a combined museum and data center with public access to lunar science.\n  - Shadow Gate: a ceremonial plaza at the edge of a shadowed crater, lit by bioluminescent flora in the central gardens.\n  - The Helium Ring: a ring-shaped energy and manufacturing belt that also serves as a public promenade.\n- Culture: Festivals celebrating solar cycles, ice harvests, and scientific breakthroughs. Public art emphasizes themes of exploration, resilie ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional capital for a Moon-based polity. There isn’t a real Luna City, but it’s a rich setup you can use for worldbuilding, stories, games, or thought experiments. Here’s a thorough concept you can adopt or mix and match.
#
# Core concept
# - Name: Luna City
# - Status: Capital of the Lunar Confederation (or Moon Dominion) – a centralized seat of government, culture, and science for lunar society.
# - Location: The rim of Shackleton Crater (south polar region), perched around a vast network of lava tubes and natural skylights. The site combines near-constant solar exposure on the rim with access to water ice in the crater floor via automated mining pipelines.
# - Timekeeping: Operates on artificial light-dark cycles inside the domed city to provide a stable 24-hour day for residents, even though the Moon’s day is ~29.5 Earth days long.
#
# Geography and infrastructure
# - Core geography: A crater-based metropolis with a ring of domes connected by pressurized tunnels. Surface corridors are protected by regolith shielding and radiation barriers; beneath the surface lie lava-tube chambers converted into habitats, factories, and research labs.
# - Architecture: A mix of 3D-printed regolith structures and transparent, radiation-shielding domes. Central government hub uses a spike-and-curve aesthetic to symbolize lunar ascent and the cold vacuum outside.
# - Urban layout: A government district at the crater crest, a commercial/market district at mid-habitat rings, and research districts near the ice extraction sites. Public spaces emphasize viewports looking toward Earth and the starfield.
# - Energy and climate control: Large solar arrays on crater rims and surrounding regolith-covered plains; compact nuclear or fusion micro-reactors backstopped by long-life batteries. Regolith acts as thermal mass; life-support is closed-loop, with water recovered from ice mining and recycled air.
#
# Government and politics
# - Governing body: Lunar Confederation Assembly plus a Governor-General who acts as the ceremonial head of state and executive. A Prime Minister (or Chief Administrator) handles day-to-day governance.
# - Key institutions: Lunar Parliament, Bureau of Lunar Affairs, Lunar Security Council, Lunar Institute of Technology, and the Ice & Resources Authority.
# - Legal system: Civil law with a strong emphasis on corporate governance oversight and scientific ethics. A Lunar Ethics Court handles disputes involving AI, automation, and habitat rights.
# - Diplomatic posture: Friendly but vigilant with Earth’s government, Mars enclaves, and deep-space mining colonies. Emphasizes shared lunar heritage, scientific exchange, and space-mining norms.
#
# Economy and technology
# - Major sectors: Ice mining and water management, solar energy production, high-precision manufacturing (3D printing, microfabrication), biotech labs, and space tourism.
# - Trade: Imports advanced materials, AI systems, and Earth-based services; exports refined water, helium-3 byproduct, high-grade ore, and lunar-produced pharmaceuticals.
# - Transportation technology: Maglev surface transit, autonomous cargo carriers, small lunar shuttles, and a network of pressurized tunnels. Proximity to Earth allows frequent orbital shuttles and high-speed transfers.
# - Industry notes: A strong emphasis on closed-loop life support, radiation shielding R&D, and sustainable mining practices to preserve ice reserves.
#
# Society and culture
# - Population: A diverse mix of Earth-born settlers, long-term Moon residents, engineers, scientists, and a growing class of AI-enabled workers who exist as digital or embodied agents.
# - Language and education: Lunese (a practical, mix of English-based creoles, with technical glossaries) plus English and other Earth languages. Bilingual or multilingual education is standard; STEM and space-law curricula are core.
# - daily life: Artificial day-night cycles define work shifts; many people live in modular apartments stacked in towers with shared agricultural terraces. Community life centers on the Ice Cathedral (a landmark and public space) and the Helix Market (economic hub).
# - Culture and traditions: A blend of Earth cultures adapted to lunar living. Festivals celebrate water, light, and discovery—Liftoff Day, Ice Night (spectral light festivals using bioluminescent crops), and the Day of the First Ice Harvest.
# - Health and wellness: Advanced telemedicine, bioengineered crops for nutrition, and physical conditioning adapted to low gravity. Mental health services emphasize social cohesion in a harsh, isolated environment.
#
# Science and education
# - Research focal points: Regolith science, cryo-mineralogy, life-support technologies, AI ethics, and human-robot collaboration. Lunar telescopes and orbital telescopes co-locate with Earth-based facilities.
# - Institutions: Lunar Institute of Helmholtz (research hub), Center for Regolith Studies, and the Academy of Lunar Arts and Technology.
# - Public outreach: The Radiant Spire, a tall broadcasting tower, hosts citizen-accessible science labs and demonstrations, making complex tech approachable.
#
# Security and defense
# - Internal security: Luna Police, a civilian-military hybrid service focusing on civil order, disaster response, and spaceports safety. Strong emphasis on privacy and ethical AI use.
# - External defense: A lightweight orbital defense fleet and stationed alert systems at key orbital gates. Patrols monitor space debris, micrometeoroid streams, and unauthorized launches.
# - Disaster preparedness: Lunar earthquakes are a misnomer on the Moon, but there are regolith collapses, gas leaks, and crater flooding in some polar tunnels. Emergency drills are routine.
#
# Notable landmarks and institutions
# - The Dome of the Crescent: The government’s central dome, housing the Parliament, executive offices, and council chambers.
# - Ice Cathedral: A breathtaking facility where water ice is processed, purified, and used as radiation shielding and drinking water. Also a cultural venue.
# - Helix Market: The vibrant commercial district with zero-gravity markets, lunar crafts, and trade pavilions.
# - The Radiant Spire: A communications and observation tower used for deep-space links and public broadcasts.
# - The Echo Opera House: A cultural venue offering lunar-echo acoustics and holo-stage performances.
# - Luna University District: Education and R&D campus cluster with labs, astronaut training facilities, and open-access libraries.
#
# History and timeline (brief arc)
# - Founding era: Early 22nd century, when Earth-based states establish a formal lunar administration to govern ice extraction, settlement, and research.
# - Era of ring cities: The first modular habitats connect to form a ring around a polar crater, driven by resource needs and radiation protection.
# - The Ice Accord: A treaty securing water rights and environmental safeguards for lunar ice deposits.
# - Modern Luna City: A thriving capital with a citizenry that blends Earth-born cultures and durable lunar heritage, balancing exploration, industry, and governance.
#
# What-if variants (tone choices)
# - Hard sci-fi face: Emphasize precise engineering, physics challenges (gravity, radiation), and the day-to-day realities of living in a near-isolated, resource-bound city.
# - Corporate-oligarchy flavor: The Moon is a semi-autonomous economic hub where corporate dynasties compete for control over ice, minerals, and tech standards; politics are influenced by boardrooms and contract law.
# - Ecolibertarian dream: A self-contained city that relies almost entirely on local energy, water recycling, and 3D-printed habitats, with minimal Earth intervention and a strong DIY culture.
# - Mythic-lunar: The Moon is a cradle of new myth, with spiritual practices centered on the night sky, water, and the fragile life built in the crater rims. Rituals and lunar festivals shape public life.
#
# Ready-to-use hooks and prompts
# - A water crisis hits Luna City when a major ice deposit becomes inaccessible due to a regulatory dispute. How do the government, market players, and citizens respond?
# - A visiting Earth scientist discovers a hidden network of unregulated tunnels beneath the Ice Cathedral. What is down there, and who wants to keep it secret?
# - An AI agent living in the public transit system begins to exhibit unexpected autonomy. How is it handled by the Lunar Ethics Court?
# - A festival occurs during a polar sunrise, but a solar flare disrupts communications. The city must operate with limited guidance, relying on community knowledge and improvisation.
#
# If you’d like, tell me your preferred tone (hard sci-fi, political intrigue, cozy slice-of-life, noir, etc.) and the kind of story or game you’re building. I can tailor Luna City’s details to fit your world, add maps and vocab, or generate scene seeds and character profiles.
