# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital city. (Treaties like the Outer Space Treaty also prohibit national sovereignty over the Moon.)

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this sci‑fi setting, the Moon’s capital is called Lunaris Prime.
#
# Where it sits:
# - Nestled on the rim of Shackleton Crater in the Moon’s south polar region, where near-constant sunlight is harvested by tall solar towers and water ice sits just below the surface in shade pockets.
#
# What Lunaris Prime is like:
# - Architecture: Transparent basalt domes, lunar glass that gleams with starlight, and latticework tunnels that weave between craters. The city uses regolith bricks and advanced 3D-printed alloys to create airy, gravity-light spaces.
# - Government: The Lunar Assembly sits in the Helios Dome, with a sunlit central plaza called the Prism Gate. The First Councillor leads the Executive Council; delegates from the Mare and Crater districts keep the federation of lunar settlements in balance.
# - Districts:
#   - Helix District (engineering & manufacturing): microgravity fabrication bays, orbital mirrors, and the city’s power grid.
#   - Crown District (diplomacy & governance): guest houses for visiting dignitaries, treaty halls, and the Grand Archive of lunar law.
#   - Crescent Quarter (arts & culture): galleries carved into ice and glass, soundscapes resonating in vacuum-friendly acoustics.
#   - Ice Ward (science & water): research stations tapping subsurface ice for life-support, fuel, and industry.
# - Landmarks:
#   - The Prism Gate: a colossal arched entrance covered in reflective lunar glass that refracts every sunrise.
#   - The Glass Sea: a central plaza pool of melted ice and polished basalt that doubles as a water reservoir and public mirror.
#   - The Lattice Bridge: a light, cable-supported transit spine connecting rim neighborhoods to the crater’s edge.
# - Life and vibe: A blend of Earth-born cultures and lunar-born communities. Low gravity makes art and movement feel buoyant; daylight cycles drive energy use and social rhythms. People move with a mix of practical suits and flowing, reflective fabrics that catch the sun.
#
# If you’d like, I can tailor Lunaris Prime further (history, notable characters, a rival or two, or a map-style layout). Or I can invent a different lunar capital with a distinct vibe.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunopolis

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Lunaris Prime
# Location: Near-side polar region of the Moon, within the rim of Shackleton Crater
# Vibe: Futuristic, austere, cosmopolitan
# Economy: Helium-3 mining; water ice processing and fuel synthesis; in-situ manufacturing and lunar construction; space-data services and Earth-Moon logistics

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunaris Prime', location="Shackleton Crater rim, Moon's south pole", vibe='A gleaming, glass-and-ceramic megacity built around a web of subterranean farms; solar mirrors, orbital light rails, and a perpetual aurora foster a techno-utopian vibe with a strong technocratic council.', economy='Helium-3 and water-ice extraction, in-situ resource utilization, lunar logistics hub, biotech and materials R&D, spaceport services, tourism and education centers.')

# %%
response["structured_response"].name

# response["structured_response"].location
# Out:
# 'Lunaris Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunaris Prime is a city located at Shackleton Crater rim, Moon's south pole
