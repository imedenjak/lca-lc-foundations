# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]},
    config
)

print(response['messages'][-1].content)
# Out:
# Nice move—leftover chicken and rice are perfect for a quick, flavorful dinner. Here are a few recipe ideas you can make, plus links if you want the full step-by-step.
#
# - Chicken Fried Rice (quick weeknight staple)
#   - Why it fits: Uses leftover rice and chicken; you can add whatever veggies you have.
#   - Quick note: usually 15–30 minutes depending on heat and veggies; great with eggs.
#   - Source ideas:
#     - Allrecipes: Chinese Chicken Fried Rice II
#     - The Recipe Critic: Better than Takeout Chicken Fried Rice
#
# - Arroz con Pollo (one-pan Latin chicken and rice)
#   - Why it fits: One-pot convenience; rice and chicken cooked together with seasonings.
#   - Quick note: can be done in about 25–40 minutes depending on the recipe.
#   - Source ideas:
#     - Skinnytaste: Arroz Con Pollo (Latin Rice and Chicken)
#     - Food & Wine: Arroz con Pollo
#
# - One-Pan Cheesy Chicken and Rice Casserole
#   - Why it fits: Cozy, satisfying bake using chicken and rice in a creamy, cheesy sauce.
#   - Quick note: typically 60–90 minutes total (includes baking time).
#   - Source idea:
#     - Tastes Better From Scratch: One Pan Cheesy Chicken Rice
#
# - Tomato Rice with Chicken and Green Beans (or similar veggie mix)
#   - Why it fits: Simple one-pan dish that uses pre-cooked chicken and rice with tomatoes.
#   - Quick note: about 30 minutes; flexible with whatever veggies you have.
#   - Source idea:
#     - Simply Recipes: Tomato Rice with Chicken and Green Beans
#
# - Classic Creamy Chicken and Rice Casserole
#   - Why it fits: Comfort-food favorite using chicken, rice, and a creamy sauce.
#   - Quick note: often baked in the oven; plan for about 45–60 minutes total.
#   - Source ideas:
#     - Delish: Best Chicken & Rice Casserole
#     - The Country Cook: Chicken and Rice Casserole
#
# Would you like full, step-by-step instructions for one or more of these? If so, tell me which dish(s) you’re leaning toward, and I’ll pull the exact ingredients and method tailored to your portions and what you have on hand. Also, any preferences (quick only, baked, with cheese, with veggies, spicy, etc.)?

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='6f821621-905c-45fc-8a8c-5fdcb2a38456'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 630, 'prompt_tokens': 199, 'total_tokens': 829, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHvPxrp260xz4sPzmSTktaKb0xJz0', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cd8d9-87ef-7b22-bb41-febc6b48e872-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'recipes using leftover chicken and rice'}, 'id': 'call_78GPgiaHdFrJnkl7bmxfgklr', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'leftover chicken and rice ideas'}, 'id': 'call_rWeUcr69lSb3n1LAJ7GTvTTE', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken fried rice recipe'}, 'id': 'call_QtH3GrRTWZKCoZxijMefppGO', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken and rice casserole recipe'}, 'id': 'call_gNtYa6FvsAaM6kdQ2pfCoELM', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'arroz con pollo recipe'}, 'id': 'call_ByNQYw585wLztiGHju3W2k3y', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 199, 'output_tokens': 630, 'total_tokens': 829, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#               ToolMessage(content='{"query": "recipes using leftover chicken and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/TheRecipeCritic/posts/grab-you-leftover-rice-and-chicken-toss-it-all-in-a-pan-and-boom-dinner-is-ready/1251345426337809/", "title": "Grab you leftover rice and chicken, toss it all in a pan, and boom ...", "content": "Just pour the uncooked rice in the casserole dish, layer the chicken (I used tenders, but breasts would work too) on top. Mix onion soup mix (", "score": 0.8896154, "raw_content": null}, {"url": "https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/", "title": "Leftover Chicken and Egg Fried Rice - Easy Peasy Foodie", "content": "Home » All Recipes » Easy Midweek Meal Ideas » **Leftover Chicken and Egg Fried Rice**. *An easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken leftovers…No leftover chicken? An easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken leftovers…No leftover chicken? And also I like my rice really crispy when I make egg fried rice which is why I tend to cook it a little longer and over a reasonably high heat – I just love those little crispy bits!! OR just notice she has UK / US toggle on the recipe.Since I’m in the US, happened to miss the toggle but was excited to use up rice, chicken & make an easy meal… I googled & I had an amazing dish in 5 minutes later.", "score": 0.8627572, "raw_content": null}, {"url": "https://therecipecritic.com/chicken-fried-rice/", "title": "Better than Takeout Chicken Fried Rice | The Recipe Critic", "content": "* **Protein-Packed Upgrade:**\xa0While I love my classic fried rice recipe, this one gets a protein boost from juicy chicken that makes it even more satisfying. ## How To Make Chicken Fried Rice. This chicken fried rice comes together fast and makes the best use of leftovers. 1. **Cook the Chicken:** Add vegetable oil\xa0and soy sauce\xa0to a\xa0large skillet\xa0or\xa0wok\xa0and heat over medium heat. 4. **Add the Rice and Serve:** Add\xa0cooked white rice\xa0and the cooked chicken to the vegetable mixture and stir to combine. ### **How to Store Leftover Chicken Fried Rice**. ## Chicken Fried Rice. This one-pan chicken fried rice is fast, flexible, and so easy. * Add 3 cups cooked rice  and the cooked chicken to the vegetable mixture and stir to combine. 30-Minute Meals, Appetizers, Asian, Carrot, Chicken, Dinner, Easy, Onion, Pea, Recipe Skill Levels, Side Dishes, Vegetables. I cook the rice the day before used leftover chicken breasts the first time.", "score": 0.82895297, "raw_content": null}, {"url": "https://streetsmartnutrition.com/easy-weeknight-fried-rice/", "title": "Rotisserie Chicken Fried Rice For An Easy Weeknight Meal", "content": "*This\xa0**Rotisserie Chicken Fried Rice**\xa0recipe uses, you guessed it, leftover rotisserie chicken with white rice, veggies, and plenty of seasoning! * How to Make Rotisserie Chicken Fried Rice. So with that out of the way, let’s get into this recipe for my **Rotisserie Chicken Fried Rice**! This is what inspired this homemade fried rice recipe because my dad always used the leftover rice to make his version of a chicken fried rice recipe the following day. ## How to Make Rotisserie Chicken Fried Rice. While I kept this Rotisserie Chicken Fried Rice recipe simple on purpose, there are plenty of ways to dress it up or customize it! I also love adding a bit of red pepper sauce (like sriracha!) when I serve my rotisserie chicken fried rice, but this is totally optional. You\'ll love this easy fried rice recipe that uses rotisserie chicken. I hope you love this\xa0**Rotisserie Chicken Fried Rice**\xa0recipe as much as we do!", "score": 0.76972175, "raw_content": null}, {"url": "https://www.simplyrecipes.com/tomato-rice-w ...
#               ToolMessage(content='{"query": "leftover chicken and rice ideas", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/groups/cheapmealideas/posts/7907950385930727/", "title": "What are some recipe ideas using leftover rice and chicken?", "content": "House Rice: Here is what I did with leftover rice and baked chicken. I deboned the chicken and added it to the rice. I added some the leftover", "score": 0.86413884, "raw_content": null}, {"url": "https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/", "title": "Leftover Chicken and Egg Fried Rice - Easy Peasy Foodie", "content": "Home » All Recipes » Easy Midweek Meal Ideas » **Leftover Chicken and Egg Fried Rice**. *An easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken leftovers…No leftover chicken? An easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken leftovers…No leftover chicken? And also I like my rice really crispy when I make egg fried rice which is why I tend to cook it a little longer and over a reasonably high heat – I just love those little crispy bits!! OR just notice she has UK / US toggle on the recipe.Since I’m in the US, happened to miss the toggle but was excited to use up rice, chicken & make an easy meal… I googled & I had an amazing dish in 5 minutes later.", "score": 0.8588255, "raw_content": null}, {"url": "https://www.facebook.com/TheRecipeCritic/posts/grab-you-leftover-rice-and-chicken-toss-it-all-in-a-pan-and-boom-dinner-is-ready/1251345426337809/", "title": "Grab you leftover rice and chicken, toss it all in a pan, and boom ...", "content": "Just pour the uncooked rice in the casserole dish, layer the chicken (I used tenders, but breasts would work too) on top. Mix onion soup mix (", "score": 0.8443195, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "This Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy", "score": 0.8055255, "raw_content": null}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice/", "title": "Chicken Fried Rice - Quick Weeknight Meals", "content": "# Chicken Fried Rice. *Simple and delicious **Chicken Fried Rice** is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.*. I used leftover rotisserie chicken and leftover rice in this. You can\'t go wrong with chicken and rice in a sesame and soy sauce. * **Green onions** - these are going in the fried rice and on top before serving. * **Cold rice** - cold rice makes the best fried rice so use leftover rice or cook the rice the night before. ## How To Make Chicken Fried Rice. * **Add remaining ingredients.** Add rice, chicken, and soy sauce. Chicken fried rice is good for up to 3 days. You can freeze chicken fried rice for up to 3 months. ## Chicken Fried Rice. Simple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner. 5. Add rice, chicken, and soy sauce.", "score": 0.76847315, "raw_content": null}], "response_time": 1.23, "request_id": "8196afaf-dd8d-48cd-95a4-2700a897df06"}', name='web_search', id='f9a85855-881e-4bb7-97c9-5b7f92b159da', tool_call_id='call_rWeUcr69lSb3n1LAJ7GTvTTE'),
#               ToolMessage(content='{"query": "chicken fried rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://thedefineddish.com/simple-chicken-fried-rice/", "title": "Easy Chicken Fried Rice - The Defined Dish", "content": "Home › Recipes › Dinner › Simple Chicken Fried Rice. # Simple Chicken Fried Rice. Listen, I know a simple chicken fried rice recipe is not ground-breaking on the Internet, but it’s such a staple in my house that I feel like I needed to have this classic on my blog somewhere for those that aren’t familiar with how simple and delicious this meal can be. The key to making this dish is to use *day-old white rice.* Rice retains a lot of moisture, and fresh rice will result in a soggy fried rice. Otherwise, this Simple Chicken Fried Rice is *so* easy to make! Add the tamari and toasted sesame oil and cook, stirring to combine, and let the sauce soak into the rice, about 2 minutes. ## Simple Chicken Fried Rice. * Add the tamari and toasted sesame oil and cook, stirring to combine and let the sauce soak into the rice, about 2 minutes.", "score": 0.99978346, "raw_content": null}, {"url": "https://therecipecritic.com/chicken-fried-rice/", "title": "Better than Takeout Chicken Fried Rice | The Recipe Critic", "content": "* **Protein-Packed Upgrade:**\xa0While I love my classic fried rice recipe, this one gets a protein boost from juicy chicken that makes it even more satisfying. ## How To Make Chicken Fried Rice. This chicken fried rice comes together fast and makes the best use of leftovers. 1. **Cook the Chicken:** Add vegetable oil\xa0and soy sauce\xa0to a\xa0large skillet\xa0or\xa0wok\xa0and heat over medium heat. 4. **Add the Rice and Serve:** Add\xa0cooked white rice\xa0and the cooked chicken to the vegetable mixture and stir to combine. ### **How to Store Leftover Chicken Fried Rice**. ## Chicken Fried Rice. This one-pan chicken fried rice is fast, flexible, and so easy. * Add 3 cups cooked rice  and the cooked chicken to the vegetable mixture and stir to combine. 30-Minute Meals, Appetizers, Asian, Carrot, Chicken, Dinner, Easy, Onion, Pea, Recipe Skill Levels, Side Dishes, Vegetables. I cook the rice the day before used leftover chicken breasts the first time.", "score": 0.9995859, "raw_content": null}, {"url": "https://www.allrecipes.com/recipe/16954/chinese-chicken-fried-rice-ii/", "title": "Chicken Fried Rice Recipe - Allrecipes", "content": "Ingredients · 1 large egg · 1 tablespoon water · 1 tablespoon butter · 1 tablespoon vegetable oil · 1 medium onion, chopped · 2 cups cooked white rice", "score": 0.9995627, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=j8PbG9KLqtA", "title": "Simple And Delicious Chicken Fried Rice Recipe - YouTube", "content": "Ingredients(4-6 servings)— 2 large eggs 1/8 tsp salt 7.05 oz/200 g chicken 3/4 tbsp soy sauce 1 tbsp mirin 1 tbsp sake 1/2 tsp brown sugar 2", "score": 0.99950445, "raw_content": null}, {"url": "https://www.averiecooks.com/easy-better-takeout-chicken-fried-rice/", "title": "Easy Better-Than-Takeout Chicken Fried Rice - Averie Cooks", "content": "**Better-Than-Takeout Chicken Fried Rice** — 🥕🥡🫛 One-skillet, ready in 20 minutes, and you’ll never want takeout again after tasting how good homemade is! * Easiest Fried Rice Recipe with Chicken. * Better-Than-Takeout Chicken Fried Rice Recipe. ## Easiest Fried Rice Recipe with Chicken. If you’ve ever wanted to learn how to make fried rice, this recipe will help you in no time! * **It’s an easy, one-skillet recipe that’s ready in 20 minutes and better than takeout.**You’ll never be tempted again to eat rice from\xa0a white takeout container after trying homemade. **For this straightforward chicken fried rice recipe, you’ll need:**. ## Recipe Variations to Try. Chicken stir-fried rice is a great clean out the fridge meal. Pineapple Fried Rice – A Hawaiian-inspired shrimp fried rice recipe that’s EASY, ready in minutes, and has so much authentic flavo ...
#               ToolMessage(content='{"query": "chicken and rice casserole recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.delish.com/cooking/recipe-ideas/a62626477/chicken-and-rice-casserole-recipe/", "title": "Best Chicken & Rice Casserole Recipe", "content": "# Chicken & Rice Casserole. ## How To Make Chicken & Rice Casserole. Plus, it adds the needed extra moisture to ensure that the rice cooks up soft and fluffy, and the casserole as a whole is moist. The mushroom soup adds a creaminess that lends to a pleasant texture, while also providing some mushroom flavor that classically works well with chicken and rice dishes. Add the chicken breasts into the hot skillet and cook for about 5 minutes on each side, before removing them from the heat and onto a plate. Turn the burner under your still-hot skillet down to medium-low and add the onion to the pan, seasoning with salt and cooking for about 10 minutes until softened and just turning brown. Carefully peel back the foil and add the shredded chicken to the top of the casserole, then cover again with the foil and allow the casserole to bake for another 10 minutes. ## What To Serve With Chicken & Rice Casserole.", "score": 0.93206495, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=HStt8K0b1yw", "title": "Easy Chicken & Rice Casserole – Comfort Food Classic! - YouTube", "content": "Easy Chicken & Rice Casserole – Comfort Food Classic!\\nEating on a Dime\\n198000 subscribers\\n643 likes\\n27670 views\\n26 Feb 2025\\n⭐️ We love that this Chicken and Rice Casserole bakes easily in a creamy sauce in a casserole dish. Get the recipe here -- https://www.eatingonadime.com/chicken-and-rice-casserole/\\n\\nMake dinnertime a breeze with this Chicken and Rice Casserole. Everything combines easily in the casserole dish for a simple ingredient casserole recipe.\\n\\n🟢 Ingredients:\\n☑️ 1 1/2 cups Long-Grain White Rice, uncooked\\n☑️ 1 10.5-ounce can of Cream of Chicken Soup\\n☑️ 1 10.5-ounce can of Cream of Mushroom Soup\\n☑️ 1 cup Water\\n☑️ 1 teaspoon Salt\\n☑️ 1/2 teaspoon Garlic Powder\\n☑️ 1/2 teaspoon Onion Powder\\n☑️ 1/4 teaspoon Black Pepper\\n☑️ 2 pounds boneless, skinless Chicken Breasts\\n☑️ 1 cup Cheddar Cheese, shredded\\n\\nGet the full recipe and nutritional information here: https://www.eatingonadime.com/chicken-and-rice-casserole/\\n\\n🔶🔶Kitchen Gadgets I Used🔶🔶\\n➡️ White Baking Dish - https://amzn.to/40YCcRP\\n➡️ Tongs - https://amzn.to/49utTRv\\n➡️ Pyrex Mixing Bowl - https://amzn.to/3UZmnYN\\n➡️ Pyrex Measuring Cups - https://amzn.to/3Vw2ysv\\n➡️ Measuring Spoons - https://amzn.to/3V4VeUd\\n➡️ Seasoning Containers - https://amzn.to/3QfxI44\\n➡️ Spatula (comes in a set) - https://amzn.to/3Qiy4qN\\n➡️ Similar Cheese Shredder - https://amzn.to/42S5cgD\\n➡️ Meat Thermometer - https://amzn.to/3Z3KU03\\n\\n🔶🔶More Casserole Recipe videos:🔶🔶\\n👉 John Wayne Casserole - https://youtu.be/a9pzjxWxpZs?si=ptmlXnctkr7uAkpk\\n\\n👉 Chicken Stuffing Bake - https://youtu.be/n2vw7qrPtuA?si=q0maci2olvPU_ZWQ\\n\\n👉 Million Dollar Spaghetti Casserole - https://youtu.be/LHsc90xZNls?si=WC5fceIvAMUPtz_1\\n41 comments\\n", "score": 0.92620385, "raw_content": null}, {"url": "https://www.thecountrycook.net/chicken-and-rice-casserole/", "title": "Chicken and Rice Casserole", "content": "Home » Dinner Recipes » Chicken and Rice Casserole. # Chicken and Rice Casserole. *This Chicken and Rice Casserole is a blast from the past. This recipe for Chicken and Rice Casserole that I am sharing today is a take on that recipe but I also added some cooked rice. * **cooked long-grain white rice** – you’ll need one cup of cooked rice for this recipe so that is 1/2 cup uncooked. * **cream of celery soup** – use whatever flavor you enjoy here: cream of chicken or cream of mushroom also work. ## HOW TO MAKE CHICKEN AND RICE CASSEROLE:. In a large bowl, stir together chicken, cooked rice, soup, mayonnaise,\xa0chicken stock and finely diced onion. ## C ...
#               ToolMessage(content='{"query": "arroz con pollo recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.foodandwine.com/arroz-con-pollo-11897964", "title": "Arroz con Pollo Recipe - Food & Wine", "content": "This one-pot Latin American dish features tender seasoned chicken and fluffy golden rice cooked together for a hearty weeknight dinner.", "score": 0.9999825, "raw_content": null}, {"url": "https://www.skinnytaste.com/arroz-con-pollo-lightened-up/", "title": "Arroz Con Pollo (Latin Rice and Chicken) | Skinnytaste", "content": "## Arroz Con Pollo (Latin Rice and Chicken). My arroz con pollo is an authentic one-pot chicken and rice dish that’s rich in tradition, easy to make, and perfect for comforting family meals. This one-pot chicken and rice dish is not only flavorful but also incredibly easy to make. My Mom’s Arroz Con Pollo recipe adds frozen mixed vegetables, and if you want a lower-carb option, try my Cauliflower “Rice” and Chicken version. ## Why You’ll Love This Latin Rice and Chicken Recipe. My mom is Colombian, and like Chicken Sancocho and Latin Yellow Rice,\xa0Arroz con Pollo is a dish I loved and still love today. Here’s what you’ll need to make this authentic arroz con pollo recipe. * **Seasonings:** I use Sazon seasoning, adobo seasoning, garlic powder, salt, black pepper and chicken bouillon which adds great flavor. Authentic Arroz Con Pollo, or Latin chicken and rice, is the ultimate one-pan meal.", "score": 0.99992275, "raw_content": null}, {"url": "https://theranchtable.com/blogs/recipes/arroz-con-pollo", "title": "Arroz con Pollo - The Ranch Table", "content": "It is a one pot recipe that makes a simple yet hearty meal. The combination of saffron, rice, meat, and vegetables creates a colorful, beautiful, and flavorful", "score": 0.9998746, "raw_content": null}, {"url": "https://muybuenoblog.com/arroz-con-pollo/", "title": "Arroz con Pollo (Mexican Chicken and Rice Recipe) - Muy Bueno", "content": "# Arroz con Pollo (Mexican Chicken and Rice). This **easy Arroz con Pollo recipe** is a traditional Mexican chicken and rice dish made in one pan — juicy chicken, fluffy rice, and tender veggies all cooking together until your kitchen smells irresistible. * Arroz con Pollo (Mexican Chicken and Rice) Recipe. Arroz con Pollo is a traditional Latin American dish that combines chicken, rice, and vegetables, all cooked together until the flavors meld into one comforting one-pot meal. It has all the flavors of Mexican Rice (Arroz Rojo) with juicy chicken simmered right in, making it a complete meal in one pan. ## Arroz con Pollo (Mexican Chicken and Rice). Cover, reduce heat, and simmer until chicken is cooked through and rice is tender, 25–30 minutes. ### Cheesy Refried Bean Dip. Crispy homemade chicken flautas served on a bed of shredded lettuce in a blue and white hand-painted dish, topped with red chile sauce, a drizzle of Mexican crema, and crumbled queso fresco – a delicious take on a classic chicken flautas recipe.", "score": 0.9998697, "raw_content": null}, {"url": "https://mydominicankitchen.com/chicken-and-rice-mexican-style-arroz-con-pollo/", "title": "Mexican Arroz con Pollo Recipe (Chicken and Rice Mexican Style)", "content": "# Mexican Arroz con Pollo Recipe (Chicken and Rice Mexican Style). *This recipe for Chicken and Rice Mexican Style (Mexican Arroz con Pollo) is a one-pot meal made with tender chicken breast, Vigo Mexican Rice, and vegetables – the perfect quick and easy weeknight dinner!*. This recipe for Chicken and Rice Mexican Style (Mexican Arroz con Pollo) is a one-pot meal made with tender chicken breast, Vigo Mexican Rice, and vegetables – the perfect quick and easy weeknight dinner! I am all about easy dinners and with the help of Vigo Mexican Rice, this one-pot Mexican style chicken and rice is a complete meal that comes together in just under 35 minutes. 9 Mexican Arroz con Pollo Recipe (Chicken and Rice Mexican Style). ## Mexica ...
#               AIMessage(content='Nice move—leftover chicken and rice are perfect for a quick, flavorful dinner. Here are a few recipe ideas you can make, plus links if you want the full step-by-step.\n\n- Chicken Fried Rice (quick weeknight staple)\n  - Why it fits: Uses leftover rice and chicken; you can add whatever veggies you have.\n  - Quick note: usually 15–30 minutes depending on heat and veggies; great with eggs.\n  - Source ideas: \n    - Allrecipes: Chinese Chicken Fried Rice II\n    - The Recipe Critic: Better than Takeout Chicken Fried Rice\n\n- Arroz con Pollo (one-pan Latin chicken and rice)\n  - Why it fits: One-pot convenience; rice and chicken cooked together with seasonings.\n  - Quick note: can be done in about 25–40 minutes depending on the recipe.\n  - Source ideas:\n    - Skinnytaste: Arroz Con Pollo (Latin Rice and Chicken)\n    - Food & Wine: Arroz con Pollo\n\n- One-Pan Cheesy Chicken and Rice Casserole\n  - Why it fits: Cozy, satisfying bake using chicken and rice in a creamy, cheesy sauce.\n  - Quick note: typically 60–90 minutes total (includes baking time).\n  - Source idea:\n    - Tastes Better From Scratch: One Pan Cheesy Chicken Rice\n\n- Tomato Rice with Chicken and Green Beans (or similar veggie mix)\n  - Why it fits: Simple one-pan dish that uses pre-cooked chicken and rice with tomatoes.\n  - Quick note: about 30 minutes; flexible with whatever veggies you have.\n  - Source idea:\n    - Simply Recipes: Tomato Rice with Chicken and Green Beans\n\n- Classic Creamy Chicken and Rice Casserole\n  - Why it fits: Comfort-food favorite using chicken, rice, and a creamy sauce.\n  - Quick note: often baked in the oven; plan for about 45–60 minutes total.\n  - Source ideas:\n    - Delish: Best Chicken & Rice Casserole\n    - The Country Cook: Chicken and Rice Casserole\n\nWould you like full, step-by-step instructions for one or more of these? If so, tell me which dish(s) you’re leaning toward, and I’ll pull the exact ingredients and method tailored to your portions and what you have on hand. Also, any preferences (quick only, baked, with cheese, with veggies, spicy, etc.)?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 3071, 'prompt_tokens': 6491, 'total_tokens': 9562, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 2560, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHvQ8MmfHGp6tBqXsQTpuyPhoQVSf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cd8d9-b0c2-75e1-97cb-12496ba4273c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6491, 'output_tokens': 3071, 'total_tokens': 9562, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 2560}})]}
