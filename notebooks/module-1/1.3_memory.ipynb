# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Ivan and my favourite colour is blue")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Ivan and my favourite colour is blue', additional_kwargs={}, response_metadata={}, id='7cb8c408-d416-4551-8bf3-a1d18d03619d'),
#               AIMessage(content='Nice to meet you, Ivan! Blue is a fantastic color—calm and versatile. Do you have a favorite shade of blue or something blue you especially like? If you’d like, I can help with blue color palettes, outfit ideas, or anything else related to your favorite color.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 387, 'prompt_tokens': 17, 'total_tokens': 404, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHmCo4d386b9YY8xhEomwgH16d7I6', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cd6bd-3339-7c73-a449-4d33f5ccf133-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 387, 'total_tokens': 404, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='1954fa44-0538-409e-bf05-b032b9fc33b0'),
#               AIMessage(content='I don’t know your favourite color yet. Want to figure it out quickly? Try this short guess:\n\n1) Do you prefer cool colors (blue/green) or warm colors (red/orange/yellow)?\n2) Do you like bright, vivid shades or muted/pastel tones?\n3) Do you want a color that’s versatile (goes with many things) or something that really stands out?\n\nTell me your answers and I’ll suggest a color. Or, if you share a few colors you like, I can guess your likely favorite.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1530, 'prompt_tokens': 11, 'total_tokens': 1541, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1408, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHmD9qCEFnZKgH6LPXgE2Sk4vtrtG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cd6bd-87b2-7f30-acf8-ee026c4548be-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 1530, 'total_tokens': 1541, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1408}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "gpt-5-nano",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Ivan and my favourite colour is blue")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Ivan and my favourite colour is blue', additional_kwargs={}, response_metadata={}, id='adaf36d1-4fbe-41ca-8cea-8e2d80307cba'),
#               AIMessage(content='Nice to meet you, Ivan. Blue is a great choice. What would you like to do today—chat about blue-related ideas, get help with something, or just talk?\n\nIf you want a quick intro you can use: “Hi, I’m Ivan. My favorite color is blue, and I enjoy [hobby].” I can tailor it to fit your interests.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 853, 'prompt_tokens': 17, 'total_tokens': 870, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHmDsElUmDdoRj5LltoisYqbjmKML', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cd6be-36f0-7f60-a2eb-8d4e2f2ca928-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 853, 'total_tokens': 870, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Ivan and my favourite colour is blue', additional_kwargs={}, response_metadata={}, id='234288c0-adb7-4615-9c82-535da1880450'),
#               AIMessage(content='Hi Ivan! Nice to meet you. Blue is a great color.\n\nWhat would you like to do today? I can help with color ideas, hex codes for blues, color palettes for a project, or just chat about blue. If you have a vibe in mind (calm, bold, nautical, etc.), tell me and I’ll suggest some blues to match.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 595, 'prompt_tokens': 17, 'total_tokens': 612, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHmEbu1z5RnsSW7RauZu0CEwJtxif', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cd6be-e514-7f41-9255-b83a17bb7cb0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 595, 'total_tokens': 612, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='7829c371-73de-4e6c-97aa-190cb92ada73'),
#               AIMessage(content='Your favourite color is blue.\n\nIf you want, I can suggest blue hex codes, palettes (calm sky blue, navy, etc.), or help with blue-themed ideas for a project. What would you like to do?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 246, 'prompt_tokens': 106, 'total_tokens': 352, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHmEiYRUvPKKaZi74LDHMKO9qlIoL', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cd6bf-02be-7f31-aca4-186d13e776f3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 106, 'output_tokens': 246, 'total_tokens': 352, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}})]}
